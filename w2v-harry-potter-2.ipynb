# %% [markdown]
# # Usando o modelo Word2Vec

# %% [markdown]
# [Neste código](https://github.com/lisaterumi/word2vec-harry-potter-portugues/blob/main/w2v-harry-potter-1.ipynb), vimos como treinar um modelo **Word2Vec** com os 7 livros do Harry Potter.
#
# Agora é hora de usar nosso modelo.

# %% [markdown]
# ### Passo 1 - importanto as bibliotecas e carregando o modelo
# Vamos importar as bibliotecas que utilizaremos e carregar o modelo. Para usar o formato binário, usamos a função ```load_word2vec_format```, caso contrário, basta usar a função ```load()```

# %%
from gensim.models import KeyedVectors
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np

# %%
w2v_model = KeyedVectors.load_word2vec_format('model_tweets_uniao.bin', binary=True)
w2v_model = Word2Vec.load("word2vec-harry-potter.model")

# %% [markdown]
# ### Passo 2 - Encontrando palavras similares
# Vamos buscar as 20 palavras mais similares a algumas palavras-chave, como nome de personagens. Como no pré-processamento, temos que escrever as palavras sem acento e apenas com caracteres alfanuméricos, senão a palavra não será encontrada no vocabulário.

# %%
w2v_model.most_similar(positive=['ron'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('hermione', 0.8969221115112305),
#  ('harry', 0.8104955554008484),
#  ('ginny', 0.7790677547454834),
#  ('amargamente', 0.7758603096008301),
#  ('oi', 0.7648736238479614),
#  ('abertamente', 0.7549736499786377),
#  ('rony', 0.7517307996749878),
#  ('dissuadir', 0.7459840178489685),
#  ('reprovador', 0.7441936731338501),
#  ('drogar', 0.7300689220428467),
#  ('inacreditavel', 0.7269477844238281),
#  ('xingar', 0.7269114255905151),
#  ('vicky', 0.725322425365448),
#  ('roucamente', 0.7189666628837585),
#  ('espreguicou', 0.7188896536827087),
#  ('entao', 0.7185559272766113),
#  ('uh', 0.7177632451057434),
#  ('impacientemente', 0.7164014577865601),
#  ('exasperar', 0.7157878279685974),
#  ('incisivamente', 0.7144197225570679)]

# %%
w2v_model.most_similar(positive=['potter'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('potters', 0.7916529774665833),
#  ('dira', 0.7798432111740112),
#  ('der', 0.7753236889839172),
#  ('evans', 0.7547593116760254),
#  ('moony', 0.7448829412460327),
#  ('lorde_treva', 0.743857741355896),
#  ('hokey', 0.7411173582077026),
#  ('oleiro', 0.7409161925315857),
#  ('comandar', 0.7376177310943604),
#  ('governador', 0.735198438167572),
#  ('destruicao', 0.7332489490509033),
#  ('srta', 0.7308906316757202),
#  ('farar', 0.728905200958252),
#  ('wormtail', 0.7283172607421875),
#  ('cornelius', 0.7257384061813354),
#  ('dum', 0.7208985090255737),
#  ('recear', 0.7192624807357788),
#  ('rodolphus', 0.7189411520957947),
#  ('ameacar', 0.7188841104507446),
#  ('lucio', 0.7181955575942993)]

# %%
w2v_model.most_similar(positive=['harry'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('atormentar', 0.8539171814918518),
#  ('entao', 0.8322420716285706),
#  ('ron', 0.8104956150054932),
#  ('hermione', 0.8049137592315674),
#  ('roucamente', 0.8012644648551941),
#  ('advogar', 0.7931739687919617),
#  ('apreensivamente', 0.7877584099769592),
#  ('novamente', 0.786112368106842),
#  ('transir', 0.7796862721443176),
#  ('binoculo', 0.7757449746131897),
#  ('rapidamente', 0.7733094096183777),
#  ('sorrir_amplamente', 0.7716755867004395),
#  ('onioculo', 0.7698922157287598),
#  ('grogue', 0.7641890048980713),
#  ('impacientemente', 0.763456404209137),
#  ('impotente', 0.7630020976066589),
#  ('energicamente', 0.7601056098937988),
#  ('atentamente', 0.7592676281929016),
#  ('consolador', 0.7591464519500732),
# ...

# %%
w2v_model.most_similar(positive=['pai'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('percival', 0.8712526559829712),
#  ('odiador', 0.8383474349975586),
#  ('ariano', 0.828083872795105),
#  ('padrinho', 0.8266212940216064),
#  ('aberracao', 0.8247341513633728),
#  ('filhar', 0.8214625120162964),
#  ('mae', 0.8196253180503845),
#  ('pareco', 0.8190063238143921),
#  ('kendra', 0.8185783624649048),
#  ('assassinar', 0.8143126368522644),
#  ('boatar', 0.8114503026008606),
#  ('sirius_black', 0.8105105757713318),
#  ('falecer', 0.7953287363052368),
#  ('filho', 0.7945705056190491),
#  ('ha_ano', 0.7841389179229736),
#  ('orfanato', 0.7799828052520752),
#  ('abortar', 0.7798729538917542),
#  ('misericordia', 0.7719522714614868),
#  ('confrontar', 0.769348680973053),
#  ('eramos', 0.7663606405258179)]

# %%
w2v_model.most_similar(positive=['mae'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('pai', 0.8196253776550293),
#  ('irma', 0.8188600540161133),
#  ('abortar', 0.7798029184341431),
#  ('padrinho', 0.7704693675041199),
#  ('filhar', 0.7647794485092163),
#  ('gabrielle', 0.7596724033355713),
#  ('irmao', 0.7413825988769531),
#  ('teddy', 0.7358275651931763),
#  ('perdao', 0.713559627532959),
#  ('maridar', 0.7044894695281982),
#  ('aberforth', 0.7019468545913696),
#  ('percival', 0.6999848484992981),
#  ('filho', 0.6956396102905273),
#  ('ariano', 0.6942974328994751),
#  ('pareco', 0.685568630695343),
#  ('tambem', 0.6837271451950073),
#  ('fleuma', 0.6824715733528137),
#  ('amigar', 0.6805985569953918),
#  ('suplicante', 0.6761597394943237),
#  ('apaixonar', 0.6743628978729248)]

# %%
w2v_model.most_similar(positive=['cicatriz'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('formigar', 0.8560631275177002),
#  ('doer', 0.8196495771408081),
#  ('raiar', 0.7983385324478149),
#  ('latejar', 0.7717836499214172),
#  ('doia', 0.7686543464660645),
#  ('arder', 0.7496475577354431),
#  ('dolorosamente', 0.7014318704605103),
#  ('cicatrizar', 0.6992411017417908),
#  ('fisica', 0.6921044588088989),
#  ('tonto', 0.6827468872070312),
#  ('testo', 0.6732003092765808),
#  ('dor', 0.6647343635559082),
#  ('doloroso', 0.662329912185669),
#  ('inconscientemente', 0.6572532057762146),
#  ('formigamento', 0.6566494703292847),
#  ('queimar', 0.6564962267875671),
#  ('livida', 0.652153730392456),
#  ('nervo', 0.6492443084716797),
#  ('parafusar', 0.6461541056632996),
#  ('frank', 0.6445055603981018)]

# %%
w2v_model.most_similar(positive=['magia'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('educacao', 0.8395903706550598),
#  ('artefatos', 0.815840482711792),
#  ('impropriar', 0.8155519366264343),
#  ('defensivo', 0.8069244027137756),
#  ('juventude', 0.7889266014099121),
#  ('especialista', 0.7827604413032532),
#  ('indevido', 0.7789070010185242),
#  ('ascensao', 0.7786481380462646),
#  ('teoria', 0.7762821316719055),
#  ('estudo', 0.7761048674583435),
#  ('detectar', 0.7759843468666077),
#  ('proibir', 0.7747317552566528),
#  ('tempo', 0.7734211087226868),
#  ('propriedade', 0.7680023908615112),
#  ('incomum', 0.7678438425064087),
#  ('comunicacao', 0.7657633423805237),
#  ('codigo', 0.7635117769241333),
#  ('situacoes', 0.7631063461303711),
#  ('fascinante', 0.7623959183692932),
# ...

# %%
w2v_model.most_similar(positive=['treva'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('cargo', 0.7195144891738892),
#  ('ensinar', 0.7151284217834473),
#  ('professor', 0.6680680513381958),
#  ('materia', 0.6619768738746643),
#  ('nom', 0.6582299470901489),
#  ('charms', 0.6562400460243225),
#  ('comandar', 0.6490097641944885),
#  ('estudar', 0.6424031257629395),
#  ('aprender', 0.6371788382530212),
#  ('qualificar', 0.6339880228042603),
#  ('orientacao', 0.6287494897842407),
#  ('empregar', 0.6272639036178589),
#  ('ex', 0.6243823766708374),
#  ('arte', 0.6233139038085938),
#  ('recrutar', 0.6207772493362427),
#  ('diferencas', 0.6197191476821899),
#  ('projeto', 0.6132501363754272),
#  ('exceder', 0.612856388092041),
#  ('contanto', 0.6126171350479126),
#  ('extraordinaria', 0.6094088554382324)]

# %%
w2v_model.most_similar(positive=['hermione'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ron', 0.89692223072052),
#  ('harry', 0.8049137592315674),
#  ('timidamente', 0.7792037725448608),
#  ('dissuadir', 0.7705632448196411),
#  ('drogar', 0.7583508491516113),
#  ('reprovador', 0.7564594745635986),
#  ('exasperar', 0.7554172277450562),
#  ('amargamente', 0.7505577802658081),
#  ('advertencia', 0.7476548552513123),
#  ('uh', 0.746500551700592),
#  ('calorosamente', 0.7426450848579407),
#  ('magoar', 0.7413856983184814),
#  ('incredulo', 0.7347638607025146),
#  ('incisivamente', 0.7327961921691895),
#  ('pansy', 0.7265182137489319),
#  ('vicky', 0.7255269885063171),
#  ('surpreso', 0.7244921326637268),
#  ('decepcionar', 0.7212912440299988),
#  ('ginny', 0.7197849154472351),
# ...

# %%
w2v_model.most_similar(positive=['dumbledore'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('dippet', 0.8425719141960144),
#  ('precisamente', 0.8285852670669556),
#  ('severus', 0.7916643619537354),
#  ('diretor', 0.7738890647888184),
#  ('snape', 0.7504847049713135),
#  ('fineas', 0.7470136284828186),
#  ('horcruxes', 0.7377511262893677),
#  ('impertinente', 0.7340367436408997),
#  ('cornelius', 0.7210163474082947),
#  ('livremente', 0.7157844305038452),
#  ('dispensar', 0.7121405601501465),
#  ('calmamente', 0.7093751430511475),
#  ('sabio', 0.7044019103050232),
#  ('voldemort', 0.7022210359573364),
#  ('slughorn', 0.6937600374221802),
#  ('misericordia', 0.6930971145629883),
#  ('excursao', 0.692786693572998),
#  ('suspensao', 0.6903423070907593),
#  ('aonde', 0.6854754686355591),
# ...

# %%
w2v_model.most_similar(positive=['severus'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('lucius', 0.8222886919975281),
#  ('calmamente', 0.8015598058700562),
#  ('dumbledore', 0.7916643619537354),
#  ('dippet', 0.7846537828445435),
#  ('snape', 0.7662785053253174),
#  ('dispensar', 0.7641316652297974),
#  ('moony', 0.7615126371383667),
#  ('questionar', 0.7452099919319153),
#  ('sabio', 0.7406370639801025),
#  ('provavel', 0.7386817932128906),
#  ('impertinente', 0.7327204942703247),
#  ('padfoot', 0.7262486219406128),
#  ('malfoys', 0.7232524156570435),
#  ('confiar', 0.722071647644043),
#  ('fineas', 0.7196321487426758),
#  ('minerva', 0.7183828353881836),
#  ('lorde_treva', 0.7149614095687866),
#  ('bella', 0.7144720554351807),
#  ('desobedecer', 0.7132827043533325),
#  ('animago', 0.7125990986824036)]

# %%
w2v_model.most_similar(positive=['snape'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('quirrell', 0.802777111530304),
#  ('severus', 0.7662785053253174),
#  ('dumbledore', 0.7504847049713135),
#  ('atrever', 0.7227597236633301),
#  ('umbridge', 0.6841483116149902),
#  ('livremente', 0.6769547462463379),
#  ('ousar', 0.6584368944168091),
#  ('detestar', 0.6581510305404663),
#  ('yaxley', 0.6547422409057617),
#  ('dippet', 0.654664933681488),
#  ('calmamente', 0.6526739597320557),
#  ('malfoy', 0.6496198177337646),
#  ('coracoes', 0.64629065990448),
#  ('voldemort', 0.6425365209579468),
#  ('lucius', 0.6411815285682678),
#  ('exultante', 0.639611005783081),
#  ('mcgonagall', 0.6363691091537476),
#  ('desestabilizar', 0.6303967237472534),
#  ('secamente', 0.6290299892425537),
# ...

# %%
w2v_model.most_similar(positive=['bom'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('melhorar', 0.7757663726806641),
#  ('cumprimento', 0.752395510673523),
#  ('tratamento', 0.7402147054672241),
#  ('beneficiar', 0.7207862734794617),
#  ('talento', 0.7194474339485168),
#  ('sao', 0.7189911603927612),
#  ('interesse', 0.7107059955596924),
#  ('irao', 0.6918764114379883),
#  ('amigo', 0.6906309723854065),
#  ('rejeitar', 0.6862592697143555),
#  ('consequencias', 0.6851535439491272),
#  ('responsaveis', 0.6849448680877686),
#  ('decente', 0.6823204755783081),
#  ('conselho', 0.681189775466919),
#  ('virao', 0.6740404367446899),
#  ('resultar', 0.673371434211731),
#  ('estrangeiro', 0.6728502511978149),
#  ('eramos', 0.6650528907775879),
#  ('aniversarios', 0.6638989448547363),
# ...

# %%
w2v_model.most_similar(positive=['rei'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('weasley', 0.8538626432418823),
#  ('ronald', 0.8228270411491394),
#  ('batedor', 0.7563273310661316),
#  ('pucey', 0.7514290809631348),
#  ('adrian', 0.7401016354560852),
#  ('arnold', 0.7263855338096619),
#  ('lee_jordan', 0.726375937461853),
#  ('spinnet', 0.7039180397987366),
#  ('pontuacao', 0.7018727660179138),
#  ('esquivo', 0.6960675120353699),
#  ('dimitrov', 0.6923206448554993),
#  ('empolgante', 0.6880331635475159),
#  ('troy', 0.6870239973068237),
#  ('marcus', 0.6865158081054688),
#  ('bastoes', 0.6796327829360962),
#  ('gol', 0.6782175898551941),
#  ('volkov', 0.6735817790031433),
#  ('ivanova', 0.6639078855514526),
#  ('atracar', 0.6625702381134033),
#  ('moran', 0.6621704697608948)]

# %%
w2v_model.most_similar(positive=['biblioteca'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('restrito', 0.8500752449035645),
#  ('aritmancia', 0.79689621925354),
#  ('revisao', 0.737007737159729),
#  ('cronograma', 0.7271131277084351),
#  ('torrar_grifinoria', 0.7208453416824341),
#  ('binns', 0.7157135009765625),
#  ('revisar', 0.7134655714035034),
#  ('estelar', 0.7108184695243835),
#  ('cancelar', 0.7094091176986694),
#  ('relutantemente', 0.7089964151382446),
#  ('sessoes', 0.7068520784378052),
#  ('agendar', 0.7060781717300415),
#  ('almoco', 0.7055889964103699),
#  ('vestiarios', 0.7031828761100769),
#  ('pesquisar', 0.6985881328582764),
#  ('si_mesmo', 0.6927403211593628),
#  ('horarios', 0.690025806427002),
#  ('domingo', 0.6890965700149536),
#  ('encaminhar', 0.687910795211792),
# ...

# %%
w2v_model.most_similar(positive=['amor'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('abencoe', 0.8556743860244751),
#  ('gracas', 0.8542261123657227),
#  ('solucao', 0.7366315126419067),
#  ('ruim', 0.6669633388519287),
#  ('revoltante', 0.6603842973709106),
#  ('ficar_surpresar', 0.6560018658638),
#  ('melhor', 0.6448051333427429),
#  ('veritaserum', 0.6359705924987793),
#  ('enganir', 0.6249722838401794),
#  ('inteligente', 0.6187624335289001),
#  ('corretivas', 0.5951026678085327),
#  ('eternar', 0.5916071534156799),
#  ('deus', 0.590847909450531),
#  ('corner', 0.5864056348800659),
#  ('estupida', 0.5837477445602417),
#  ('fortalecimento', 0.5823771357536316),
#  ('patetico', 0.5821694135665894),
#  ('talento', 0.5811406373977661),
#  ('envelhecimento', 0.577515721321106),
# ...

# %%
w2v_model.most_similar(positive=['inimigo'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('identidade', 0.8465590476989746),
#  ('igual', 0.8187220692634583),
#  ('existencia', 0.8112106919288635),
#  ('vincular', 0.8014353513717651),
#  ('possuidor', 0.8007450103759766),
#  ('lord_voldemort', 0.7909042239189148),
#  ('prematuro', 0.7873013615608215),
#  ('verdadeiramente', 0.7868143320083618),
#  ('torturar', 0.7849880456924438),
#  ('precioso', 0.7828529477119446),
#  ('mortal', 0.7825900912284851),
#  ('hallows', 0.7817443609237671),
#  ('bravura', 0.7813331484794617),
#  ('confrontar', 0.7793781757354736),
#  ('responsabilidade', 0.7792503833770752),
#  ('dom', 0.7782359719276428),
#  ('heroi', 0.776049017906189),
#  ('fraqueza', 0.7744536995887756),
#  ('fiel', 0.7722288966178894),
# ...

# %%
w2v_model.most_similar(positive=['lord_voldemort'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('espiao', 0.8395299911499023),
#  ('vitimar', 0.8230382204055786),
#  ('conexao', 0.8194418549537659),
#  ('riddles', 0.8159182071685791),
#  ('identidade', 0.814128041267395),
#  ('voldemort', 0.8091344833374023),
#  ('ressuscitar', 0.8049381971359253),
#  ('seguidor', 0.8017321228981018),
#  ('evidenciar', 0.8001101016998291),
#  ('possuir', 0.7993494272232056),
#  ('horcruxes', 0.7972729802131653),
#  ('grindelwald', 0.7931305766105652),
#  ('prematuro', 0.79244065284729),
#  ('fraqueza', 0.7920761108398438),
#  ('inimigo', 0.7909042239189148),
#  ('imaginacao', 0.7905895113945007),
#  ('paradeiro', 0.790175199508667),
#  ('lorde_treva', 0.784356951713562),
#  ('bravura', 0.781275749206543),
# ...

# %%
w2v_model.most_similar(positive=['cedric'], topn=20)
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('cedrico', 0.8365216851234436),
#  ('viktor', 0.7613920569419861),
#  ('diggory', 0.7538579702377319),
#  ('chang', 0.7487868666648865),
#  ('amo', 0.7373173236846924),
#  ('krum', 0.7285282611846924),
#  ('fleur_delacour', 0.7032307386398315),
#  ('vitor', 0.6567206382751465),
#  ('empatar', 0.6559010744094849),
#  ('favor', 0.637464165687561),
#  ('cho', 0.6351646780967712),
#  ('apanhadora', 0.6261224150657654),
#  ('roger', 0.621628999710083),
#  ('corvinal', 0.6162959933280945),
#  ('emblemar', 0.6142617464065552),
#  ('seeker', 0.6133298873901367),
#  ('feder', 0.607753336429596),
#  ('carrow', 0.5974486470222473),
#  ('penelope', 0.5960681438446045),
#  ('davies', 0.5957813262939453)]

# %% [markdown]
# ### Passo 3 - Grau de similaridade
# Agora, vamos medir o quanto duas palavras são similarses, ou seja, o quanto elas aparecem no mesmo contexto ao longo dos sete livros.

# %%
w2v_model.wv.similarity("doenca", 'dor')
# Out:
# 0.17418802

# %%
w2v_model.wv.similarity("pessoa", 'animal')
# Out:
# 0.21465863

# %% [markdown]
# ### Passo 4 - Palavra fora de contexto
# Das palavras enviadas, qual está fora do contexto?
#
# Vimos que às vezes os resultados não fazem muito sentido para nós, humanos.. Lembre-se de que isso foi gerado de acordo com a forma em que as palavras estavam em nosso corpus.

# %%
w2v_model.wv.doesnt_match(['hipertireoidismo', 'sal', 'carboidrato'])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'sal'

# %%
w2v_model.wv.doesnt_match(['harry_potter', 'hermione', 'drako'])
# Out:
# 'hermione'

# %% [markdown]
# ### Passo 5 - Analogias
#
# Qual palavra está para **terra** assim como **chuva** está para **sol**?

# %%
w2v_model.wv.most_similar(positive=["terra", "chuva"], negative=["sol"], topn=3)
# Out:
# [('encharcar', 0.6218206882476807),
#  ('lama', 0.6132452487945557),
#  ('pele', 0.607527494430542)]

# %%
w2v_model.wv.most_similar(positive=["montanha", "nuvem"], negative=["casa"], topn=3)
# Out:
# [('ceu', 0.7454904317855835),
#  ('estrelar', 0.7328280806541443),
#  ('nevoar', 0.7216001749038696)]

# %%
w2v_model.wv.most_similar(positive=["escola", "sala"], negative=["trem"], topn=3)
# Out:
# [('troféu', 0.6912025809288025),
#  ('alunar', 0.6855142116546631),
#  ('camara', 0.675255298614502)]

# %% [markdown]
# ### Passo 6 - Top palavras mais e menos similares

# %%
w2v_model.wv.most_similar(positive=["noite"],topn=3)
# Out:
# [('halloween', 0.8446013331413269),
#  ('horar', 0.80884850025177),
#  ('semestre', 0.80645352602005)]

# %%
w2v_model.wv.most_similar(negative=["noite"],topn=3)
# Out:
# [('orelhar', 0.3742062449455261),
#  ('brandir', 0.35184550285339355),
#  ('imundo', 0.32256144285202026)]

# %% [markdown]
# ### Passo 7 - Visualização t-SNE
# Vamos plotar nossos vetores de 32 dimensões em gráficos bidimensionais para tentar encontrar padrões interessantes.
#
# Para isso, usaremos a implementação ```t-SNE``` do ```scikit-learn```.
#
# Para tornar as visualizações mais relevantes, examinaremos as relações entre uma palavra de consulta (em vermelho), suas palavras mais semelhantes no modelo (em azul) e outras palavras do vocabulário (em verde).

# %%
def tsnescatterplot(model, word, list_names):
    # Plota os resultados do algoritmo de redução de dimensionalidade t-SNE dos vetores de uma palavra de consulta,
    # sua lista de palavras mais semelhantes e uma lista de palavras.
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adiciona o vetor da palavra de consulta
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # pega a lsita das palavras mais similares
    close_words = model.wv.most_similar([word])
    
    # adiciona o vetor de cada uma das palavras mais proximas no array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adiciona o vetor de cada uma das palavras da lista list_names ao array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduz a dimensionalidade com PCA
    reduc = PCA(n_components=18).fit_transform(arrays)
    
    # Encontra as coorendadas t-SNE para duas dimensoes
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Seta as variaveis para plotar
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Grafico basico
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adiciona anotações com um loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
wordT = 'escola'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   after removing the cwd from sys.path.

# %%
wordT = 'hermione'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'ron'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'harry'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'dragao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'aranha'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'medo'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'amizade'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'felicidade'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'emocao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'lutar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'estudar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'professor'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'serpente'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'hogwarts'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'grifinoria'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'quadribol'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'sonserina'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'corvinal'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'lufar_lufar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'apaixonar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wordT = 'fim'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.most_similar(positive=[wordT], topn=20)])
# Out:
# C:\Users\lisat\anaconda3\envs\word2vec\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Vamos gerar um gráfico diferente agora. Vamos ver como os personagens estão relacionados entre si e quais as 10 palavras mais próximas a cada um deles.

# %%
keys = ['hermione', 'harry', 'ron', 'malfoy', 'dumbledore', 'severus']


embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in model.most_similar(word, topn=10):
        words.append(similar_word)
        embeddings.append(model[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)


from sklearn.manifold import TSNE
import numpy as np

embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

import matplotlib.pyplot as plt
import matplotlib.cm as cm

def tsne_plot_similar_words(title, labels, embedding_clusters, word_clusters, a, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=a, label=label)
        for i, word in enumerate(words):
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=16)
    #plt.legend(loc=4)
    plt.legend()
    plt.title(title)
    plt.grid(True)
    if filename:
        plt.savefig(filename, format='png', dpi=300, bbox_inches='tight')
    plt.show()


tsne_plot_similar_words('Similaridade entre palavras associadas aos personagens', keys, embeddings_en_2d, word_clusters, 0.7, 'similar_words_new.png')

# %% [markdown]
# Será gerado essa imagem:
#
# ![t-SNE](img/tsne.png)

# %% [markdown]
# Agora, vamos [gerar nuvens de palavras](#) para cada um dos livros em separado.
